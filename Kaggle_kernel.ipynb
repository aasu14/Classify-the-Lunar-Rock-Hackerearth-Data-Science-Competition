# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/DataSet/test.csv
# /kaggle/input/DataSet/train.csv
# /kaggle/input/DataSet/Test Images/lg168 (403).png
# /kaggle/input/DataSet/Test Images/lg45 (496).png
# /kaggle/input/DataSet/Test Images/lg45 (94).png
# /kaggle/input/DataSet/Test Images/lg45 (186).png
# /kaggle/input/DataSet/Test Images/lg56 (115).png
# /kaggle/input/DataSet/Test Images/lg167 (21).png
# /kaggle/input/DataSet/Test Images/lg56 (191).png
# /kaggle/input/DataSet/Test Images/lg 988 (6).png
# /kaggle/input/DataSet/Test Images/lg99 (23).png
# /kaggle/input/DataSet/Test Images/lg168 (269).png
# /kaggle/input/DataSet/Test Images/lg45 (176).png
# /kaggle/input/DataSet/Test Images/lgl60 (57).png
# /kaggle/input/DataSet/Test Images/lg566 (300).png
# /kaggle/input/DataSet/Test Images/lgl125 (289).png
# /kaggle/input/DataSet/Test Images/lg432 (217).png
# /kaggle/input/DataSet/Test Images/lgl125 (148).png
# /kaggle/input/DataSet/Test Images/lg56 (195).png
# /kaggle/input/DataSet/Test Images/lg169 (118).png
# /kaggle/input/DataSet/Test Images/lg56 (145).png
# /kaggle/input/DataSet/Test Images/lg171 (335).png
# /kaggle/input/DataSet/Test Images/lg171 (320).png
# /kaggle/input/DataSet/Test Images/lgl125 (30).png
# /kaggle/input/DataSet/Test Images/lg45 (509).png
# /kaggle/input/DataSet/Test Images/lg168 (220).png
# /kaggle/input/DataSet/Test Images/lg99 (67).png
# /kaggle/input/DataSet/Test Images/lg87 (328).png
# /kaggle/input/DataSet/Test Images/lg898 (339).png
# /kaggle/input/DataSet/Test Images/lg45 (23).png
# /kaggle/input/DataSet/Test Images/lgl85 (169).png
# /kaggle/input/DataSet/Test Images/lg 988 (168).png
# /kaggle/input/DataSet/Test Images/lg101 (37).png
# /kaggle/input/DataSet/Test Images/lg56 (92).png
# /kaggle/input/DataSet/Test Images/lgl305 (100).png
# /kaggle/input/DataSet/Test Images/lg171 (154).png
# /kaggle/input/DataSet/Test Images/lg101 (279).png
# /kaggle/input/DataSet/Test Images/lg898 (226).png
# /kaggle/input/DataSet/Test Images/lg168 (58).png
# /kaggle/input/DataSet/Test Images/lg101 (322).png
# /kaggle/input/DataSet/Test Images/lg170 (209).png
# /kaggle/input/DataSet/Test Images/lg56 (99).png
# /kaggle/input/DataSet/Test Images/lg566 (459).png
# /kaggle/input/DataSet/Test Images/lg45 (279).png
# /kaggle/input/DataSet/Test Images/lg167 (35).png
# /kaggle/input/DataSet/Test Images/lg 988 (31).png
# /kaggle/input/DataSet/Test Images/lg171 (365).png
# /kaggle/input/DataSet/Test Images/lgl30 (27).png
# /kaggle/input/DataSet/Test Images/lg99 (104).png
# /kaggle/input/DataSet/Test Images/lgl60 (100).png
# /kaggle/input/DataSet/Test Images/lgl305 (221).png
# /kaggle/input/DataSet/Test Images/lgl85 (303).png
# /kaggle/input/DataSet/Test Images/lg170 (38).png
# /kaggle/input/DataSet/Test Images/lg101 (12).png
# /kaggle/input/DataSet/Test Images/lg87 (278).png
# /kaggle/input/DataSet/Test Images/lg566 (455).png
# /kaggle/input/DataSet/Test Images/lgl85 (177).png
# /kaggle/input/DataSet/Test Images/lg169 (167).png
# /kaggle/input/DataSet/Test Images/lg566 (462).png
# /kaggle/input/DataSet/Test Images/lgl60 (53).png
# /kaggle/input/DataSet/Test Images/lg432 (101).png
# /kaggle/input/DataSet/Test Images/lg56 (176).png
# /kaggle/input/DataSet/Test Images/lgl85 (105).png
# /kaggle/input/DataSet/Test Images/lg898 (279).png
# /kaggle/input/DataSet/Test Images/lg87 (62).png
# /kaggle/input/DataSet/Test Images/lg 988 (224).png
# /kaggle/input/DataSet/Test Images/lg566 (328).png
# /kaggle/input/DataSet/Test Images/lg432 (513).png
# /kaggle/input/DataSet/Test Images/lg45 (60).png
# /kaggle/input/DataSet/Test Images/lg45 (455).png
# /kaggle/input/DataSet/Test Images/lg167 (118).png
# /kaggle/input/DataSet/Test Images/lg169 (42).png
# /kaggle/input/DataSet/Test Images/lg171 (379).png
# /kaggle/input/DataSet/Test Images/lg168 (247).png
# /kaggle/input/DataSet/Test Images/lgl125 (71).png
# /kaggle/input/DataSet/Test Images/lg898 (69).png
# /kaggle/input/DataSet/Test Images/lgl125 (412).png
# /kaggle/input/DataSet/Test Images/lg76 (161).png
# /kaggle/input/DataSet/Test Images/lg171 (141).png
# /kaggle/input/DataSet/Test Images/lgl85 (441).png
# /kaggle/input/DataSet/Test Images/lg168 (226).png
# /kaggle/input/DataSet/Test Images/lgl305 (234).png
# /kaggle/input/DataSet/Test Images/lgl60 (32).png
# /kaggle/input/DataSet/Test Images/lg 988 (200).png
# /kaggle/input/DataSet/Test Images/lg167 (82).png
# /kaggle/input/DataSet/Test Images/lg99 (228).png
# /kaggle/input/DataSet/Test Images/lg 988 (181).png
# /kaggle/input/DataSet/Test Images/lgl125 (352).png
# /kaggle/input/DataSet/Test Images/lg168 (343).png
# /kaggle/input/DataSet/Test Images/lgl85 (9).png
# /kaggle/input/DataSet/Test Images/lg566 (48).png
# /kaggle/input/DataSet/Test Images/lg87 (185).png
# /kaggle/input/DataSet/Test Images/lg898 (120).png
# /kaggle/input/DataSet/Test Images/lg87 (124).png
# /kaggle/input/DataSet/Test Images/lg45 (202).png
# /kaggle/input/DataSet/Test Images/lg45 (301).png
# /kaggle/input/DataSet/Test Images/lg171 (103).png
# /kaggle/input/DataSet/Test Images/lg99 (161).png
# /kaggle/input/DataSet/Test Images/lg 988 (344).png
# /kaggle/input/DataSet/Test Images/lg87 (111).png
# /kaggle/input/DataSet/Test Images/lg87 (13).png
# /kaggle/input/DataSet/Test Images/lgl85 (398).png
# /kaggle/input/DataSet/Test Images/lgl125 (531).png
# /kaggle/input/DataSet/Test Images/lgl60 (201).png
# /kaggle/input/DataSet/Test Images/lg898 (263).png
# /kaggle/input/DataSet/Test Images/lg56 (293).png
# /kaggle/input/DataSet/Test Images/lg 988 (300).png
# /kaggle/input/DataSet/Test Images/lg45 (361).png
# /kaggle/input/DataSet/Test Images/lg87 (296).png
# /kaggle/input/DataSet/Test Images/lgl305 (156).png
# /kaggle/input/DataSet/Test Images/lg101 (149).png
# /kaggle/input/DataSet/Test Images/lg898 (264).png
# /kaggle/input/DataSet/Test Images/lgl60 (329).png
# /kaggle/input/DataSet/Test Images/lg432 (371).png
# /kaggle/input/DataSet/Test Images/lgl305 (138).png
# /kaggle/input/DataSet/Test Images/lg898 (274).png
# /kaggle/input/DataSet/Test Images/lgl305 (32).png
# /kaggle/input/DataSet/Test Images/lg45 (416).png
# /kaggle/input/DataSet/Test Images/lg99 (14).png
# /kaggle/input/DataSet/Test Images/lg99 (64).png
# /kaggle/input/DataSet/Test Images/lgl60 (335).png
# /kaggle/input/DataSet/Test Images/lg566 (353).png
# /kaggle/input/DataSet/Test Images/lg432 (93).png
# /kaggle/input/DataSet/Test Images/lg171 (209).png
# /kaggle/input/DataSet/Test Images/lg56 (179).png
# /kaggle/input/DataSet/Test Images/lg432 (304).png
# /kaggle/input/DataSet/Test Images/lgl85 (476).png
# /kaggle/input/DataSet/Test Images/lg45 (26).png
# /kaggle/input/DataSet/Test Images/lg45 (175).png
# /kaggle/input/DataSet/Test Images/lg56 (278).png
# /kaggle/input/DataSet/Test Images/lg76 (166).png
# /kaggle/input/DataSet/Test Images/lg101 (94).png
# /kaggle/input/DataSet/Test Images/lg56 (64).png
# /kaggle/input/DataSet/Test Images/lg99 (180).png
# /kaggle/input/DataSet/Test Images/lg56 (221).png
# /kaggle/input/DataSet/Test Images/lgl85 (315).png
# /kaggle/input/DataSet/Test Images/lgl305 (143).png
# /kaggle/input/DataSet/Test Images/lg566 (419).png
# /kaggle/input/DataSet/Test Images/lgl125 (429).png
# /kaggle/input/DataSet/Test Images/lg432 (399).png
# /kaggle/input/DataSet/Test Images/lg432 (55).png
# /kaggle/input/DataSet/Test Images/lgl60 (163).png
# /kaggle/input/DataSet/Test Images/lg171 (434).png
# /kaggle/input/DataSet/Test Images/lg171 (6).png
# /kaggle/input/DataSet/Test Images/lg171 (131).png
# /kaggle/input/DataSet/Test Images/lg87 (457).png
# /kaggle/input/DataSet/Test Images/lg168 (378).png
# /kaggle/input/DataSet/Test Images/lgl60 (84).png
# /kaggle/input/DataSet/Test Images/lgl305 (264).png
# /kaggle/input/DataSet/Test Images/lg76 (84).png
# /kaggle/input/DataSet/Test Images/lg87 (117).png
# /kaggle/input/DataSet/Test Images/lgl125 (363).png
# /kaggle/input/DataSet/Test Images/lgl85 (500).png
# /kaggle/input/DataSet/Test Images/lg87 (251).png
# /kaggle/input/DataSet/Test Images/lg101 (281).png
# /kaggle/input/DataSet/Test Images/lg45 (160).png
# /kaggle/input/DataSet/Test Images/lgl305 (206).png
# /kaggle/input/DataSet/Test Images/lg169 (64).png
# /kaggle/input/DataSet/Test Images/lg566 (235).png
# /kaggle/input/DataSet/Test Images/lg170 (124).png
# /kaggle/input/DataSet/Test Images/lg56 (264).png
# /kaggle/input/DataSet/Test Images/lg45 (173).png
# /kaggle/input/DataSet/Test Images/lgl 10 (18).png
# /kaggle/input/DataSet/Test Images/lg 988 (288).png
# /kaggle/input/DataSet/Test Images/lg99 (209).png
# /kaggle/input/DataSet/Test Images/lg 988 (382).png
# /kaggle/input/DataSet/Test Images/lgl125 (321).png
# /kaggle/input/DataSet/Test Images/lg45 (137).png
# /kaggle/input/DataSet/Test Images/lg 988 (171).png
# /kaggle/input/DataSet/Test Images/lg566 (42).png
# /kaggle/input/DataSet/Test Images/lg101 (177).png
# /kaggle/input/DataSet/Test Images/lg45 (427).png
# /kaggle/input/DataSet/Test Images/lgl125 (231).png
# /kaggle/input/DataSet/Test Images/lgl85 (311).png
# /kaggle/input/DataSet/Test Images/lgl30 (110).png
# /kaggle/input/DataSet/Test Images/lg56 (177).png
# /kaggle/input/DataSet/Test Images/lg76 (114).png
# /kaggle/input/DataSet/Test Images/lg566 (16).png
# /kaggle/input/DataSet/Test Images/lg169 (87).png
# /kaggle/input/DataSet/Test Images/lgl85 (157).png
# /kaggle/input/DataSet/Test Images/lgl125 (172).png
# /kaggle/input/DataSet/Test Images/lg45 (133).png
# /kaggle/input/DataSet/Test Images/lg 988 (21).png
# /kaggle/input/DataSet/Test Images/lgl60 (302).png
# /kaggle/input/DataSet/Test Images/lgl60 (396).png
# /kaggle/input/DataSet/Test Images/lg45 (471).png
# /kaggle/input/DataSet/Test Images/lgl85 (516).png
# /kaggle/input/DataSet/Test Images/lgl305 (232).png
# /kaggle/input/DataSet/Test Images/lg101 (96).png
# /kaggle/input/DataSet/Test Images/lg167 (96).png
# /kaggle/input/DataSet/Test Images/lg898 (206).png
# /kaggle/input/DataSet/Test Images/lg56 (186).png
# /kaggle/input/DataSet/Test Images/lg169 (111).png
# /kaggle/input/DataSet/Test Images/lg56 (40).png
# /kaggle/input/DataSet/Test Images/lgl60 (19).png
# /kaggle/input/DataSet/Test Images/lg45 (268).png
# /kaggle/input/DataSet/Test Images/lg432 (410).png
# /kaggle/input/DataSet/Test Images/lg432 (474).png
# /kaggle/input/DataSet/Test Images/lgl125 (280).png
# /kaggle/input/DataSet/Test Images/lg566 (441).png
# /kaggle/input/DataSet/Test Images/lg432 (466).png
# /kaggle/input/DataSet/Test Images/lgl125 (294).png
# /kaggle/input/DataSet/Test Images/lg167 (170).png
# /kaggle/input/DataSet/Test Images/lg432 (172).png
# /kaggle/input/DataSet/Test Images/lg170 (233).png
# /kaggle/input/DataSet/Test Images/lg432 (18).png
# /kaggle/input/DataSet/Test Images/lg56 (234).png
# /kaggle/input/DataSet/Test Images/lg170 (137).png
# /kaggle/input/DataSet/Test Images/lg566 (110).png
# /kaggle/input/DataSet/Test Images/lg76 (136).png
# /kaggle/input/DataSet/Test Images/lg 988 (132).png
# /kaggle/input/DataSet/Test Images/lg168 (348).png
# /kaggle/input/DataSet/Test Images/lg45 (38).png
# /kaggle/input/DataSet/Test Images/lgl85 (75).png
# /kaggle/input/DataSet/Test Images/lg45 (414).png
# /kaggle/input/DataSet/Test Images/lgl125 (362).png
# /kaggle/input/DataSet/Test Images/lg169 (35).png
# /kaggle/input/DataSet/Test Images/lgl60 (277).png
# /kaggle/input/DataSet/Test Images/lg45 (419).png
# /kaggle/input/DataSet/Test Images/lg 988 (44).png
# /kaggle/input/DataSet/Test Images/lgl85 (296).png
# /kaggle/input/DataSet/Test Images/lg432 (73).png
# /kaggle/input/DataSet/Test Images/lg168 (223).png
# /kaggle/input/DataSet/Test Images/lg898 (16).png
# /kaggle/input/DataSet/Test Images/lg99 (133).png
# /kaggle/input/DataSet/Test Images/lg76 (21).png
# /kaggle/input/DataSet/Test Images/lg99 (56).png
# /kaggle/input/DataSet/Test Images/lg101 (213).png
# /kaggle/input/DataSet/Test Images/lg45 (98).png
# /kaggle/input/DataSet/Test Images/lg87 (433).png
# /kaggle/input/DataSet/Test Images/lgl125 (264).png
# /kaggle/input/DataSet/Test Images/lgl60 (274).png
# /kaggle/input/DataSet/Test Images/lg168 (95).png
# /kaggle/input/DataSet/Test Images/lg169 (224).png
# /kaggle/input/DataSet/Test Images/lg566 (271).png
# /kaggle/input/DataSet/Test Images/lg101 (128).png
# /kaggle/input/DataSet/Test Images/lg101 (168).png
# /kaggle/input/DataSet/Test Images/lgl85 (162).png
# /kaggle/input/DataSet/Test Images/lgl60 (271).png
# /kaggle/input/DataSet/Test Images/lg87 (96).png
# /kaggle/input/DataSet/Test Images/lg432 (415).png
# /kaggle/input/DataSet/Test Images/lg898 (62).png
# /kaggle/input/DataSet/Test Images/lgl85 (412).png
# /kaggle/input/DataSet/Test Images/lg432 (299).png
# /kaggle/input/DataSet/Test Images/lgl125 (340).png
# /kaggle/input/DataSet/Test Images/lg 988 (172).png
# /kaggle/input/DataSet/Test Images/lg898 (343).png
# /kaggle/input/DataSet/Test Images/lg87 (166).png
# /kaggle/input/DataSet/Test Images/lg170 (151).png
# /kaggle/input/DataSet/Test Images/lg566 (37).png
# /kaggle/input/DataSet/Test Images/lg87 (279).png
# /kaggle/input/DataSet/Test Images/lg76 (144).png
# /kaggle/input/DataSet/Test Images/lg45 (188).png
# /kaggle/input/DataSet/Test Images/lgl60 (72).png
# /kaggle/input/DataSet/Test Images/lg99 (75).png
# /kaggle/input/DataSet/Test Images/lg898 (127).png
# /kaggle/input/DataSet/Test Images/lgl305 (46).png
# /kaggle/input/DataSet/Test Images/lg45 (534).png
# /kaggle/input/DataSet/Test Images/lg167 (61).png
# /kaggle/input/DataSet/Test Images/lg99 (128).png
# /kaggle/input/DataSet/Test Images/lgl85 (458).png
# /kaggle/input/DataSet/Test Images/lg101 (8).png
# /kaggle/input/DataSet/Test Images/lg45 (332).png
# /kaggle/input/DataSet/Test Images/lg432 (339).png
# /kaggle/input/DataSet/Test Images/lg101 (278).png
# /kaggle/input/DataSet/Test Images/lg171 (10).png
# /kaggle/input/DataSet/Test Images/lg87 (354).png
# /kaggle/input/DataSet/Test Images/lg898 (90).png
# /kaggle/input/DataSet/Test Images/lg170 (150).png
# /kaggle/input/DataSet/Test Images/lg566 (146).png
# /kaggle/input/DataSet/Test Images/lg45 (444).png
# /kaggle/input/DataSet/Test Images/lgl125 (434).png
# /kaggle/input/DataSet/Test Images/lgl60 (13).png
# /kaggle/input/DataSet/Test Images/lg898 (309).png
# /kaggle/input/DataSet/Test Images/lg45 (252).png
# /kaggle/input/DataSet/Test Images/lg56 (86).png
# /kaggle/input/DataSet/Test Images/lg101 (280).png
# /kaggle/input/DataSet/Test Images/lg170 (118).png
# /kaggle/input/DataSet/Test Images/lg169 (48).png
# /kaggle/input/DataSet/Test Images/lg566 (191).png
# /kaggle/input/DataSet/Test Images/lg167 (88).png
# /kaggle/input/DataSet/Test Images/lg432 (283).png
# /kaggle/input/DataSet/Test Images/lg168 (414).png
# /kaggle/input/DataSet/Test Images/lg169 (185).png
# /kaggle/input/DataSet/Test Images/lg 988 (115).png
# /kaggle/input/DataSet/Test Images/lgl60 (360).png
# /kaggle/input/DataSet/Test Images/lg432 (222).png
# /kaggle/input/DataSet/Test Images/lgl305 (87).png
# /kaggle/input/DataSet/Test Images/lg87 (429).png
# /kaggle/input/DataSet/Test Images/lgl125 (94).png
# /kaggle/input/DataSet/Test Images/lg45 (428).png
# /kaggle/input/DataSet/Test Images/lgl85 (475).png
# /kaggle/input/DataSet/Test Images/lg87 (466).png
# /kaggle/input/DataSet/Test Images/lg171 (295).png
# /kaggle/input/DataSet/Test Images/lg45 (124).png
# /kaggle/input/DataSet/Test Images/lg45 (366).png
# /kaggle/input/DataSet/Test Images/lg566 (464).png
# /kaggle/input/DataSet/Test Images/lg45 (426).png
# /kaggle/input/DataSet/Test Images/lg87 (467).png
# /kaggle/input/DataSet/Test Images/lg566 (54).png
# /kaggle/input/DataSet/Test Images/lgl305 (249).png
# /kaggle/input/DataSet/Test Images/lg87 (46).png
# /kaggle/input/DataSet/Test Images/lgl85 (136).png
# /kaggle/input/DataSet/Test Images/lgl85 (317).png
# /kaggle/input/DataSet/Test Images/lg168 (421).png
# /kaggle/input/DataSet/Test Images/lg87 (188).png
# /kaggle/input/DataSet/Test Images/lgl85 (196).png
# /kaggle/input/DataSet/Test Images/lg168 (147).png
# /kaggle/input/DataSet/Test Images/lg566 (74).png
# /kaggle/input/DataSet/Test Images/lgl60 (109).png
# /kaggle/input/DataSet/Test Images/lg566 (52).png
# /kaggle/input/DataSet/Test Images/lgl125 (337).png
# /kaggle/input/DataSet/Test Images/lgl60 (278).png
# /kaggle/input/DataSet/Test Images/lg45 (223).png
# /kaggle/input/DataSet/Test Images/lgl125 (400).png
# /kaggle/input/DataSet/Test Images/lg87 (384).png
# /kaggle/input/DataSet/Test Images/lg101 (163).png
# /kaggle/input/DataSet/Test Images/lg167 (148).png
# /kaggle/input/DataSet/Test Images/lg101 (203).png
# /kaggle/input/DataSet/Test Images/lgl60 (337).png
# /kaggle/input/DataSet/Test Images/lg167 (49).png
# /kaggle/input/DataSet/Test Images/lg99 (66).png
# /kaggle/input/DataSet/Test Images/lg171 (463).png
# /kaggle/input/DataSet/Test Images/lgl85 (397).png
# /kaggle/input/DataSet/Test Images/lg898 (35).png
# /kaggle/input/DataSet/Test Images/lgl125 (350).png
# /kaggle/input/DataSet/Test Images/lgl125 (219).png
# /kaggle/input/DataSet/Test Images/lg432 (465).png
# /kaggle/input/DataSet/Test Images/lg87 (138).png
# /kaggle/input/DataSet/Test Images/lg566 (268).png
# /kaggle/input/DataSet/Test Images/lgl60 (55).png
# /kaggle/input/DataSet/Test Images/lg169 (161).png
# /kaggle/input/DataSet/Test Images/lg432 (74).png
# /kaggle/input/DataSet/Test Images/lg101 (171).png
# /kaggle/input/DataSet/Test Images/lg99 (232).png
# /kaggle/input/DataSet/Test Images/lgl85 (22).png
# /kaggle/input/DataSet/Test Images/lgl125 (14).png
# /kaggle/input/DataSet/Test Images/lgl60 (124).png
# /kaggle/input/DataSet/Test Images/lgl60 (102).png
# /kaggle/input/DataSet/Test Images/lg76 (188).png
# /kaggle/input/DataSet/Test Images/lg167 (70).png
# /kaggle/input/DataSet/Test Images/lg45 (541).png
# /kaggle/input/DataSet/Test Images/lg170 (228).png
# /kaggle/input/DataSet/Test Images/lgl125 (347).png
# /kaggle/input/DataSet/Test Images/lg99 (219).png
# /kaggle/input/DataSet/Test Images/lg898 (171).png
# /kaggle/input/DataSet/Test Images/lg76 (77).png
# /kaggle/input/DataSet/Test Images/lg167 (112).png
# /kaggle/input/DataSet/Test Images/lg 988 (296).png
# /kaggle/input/DataSet/Test Images/lg171 (514).png
# /kaggle/input/DataSet/Test Images/lg169 (133).png
# /kaggle/input/DataSet/Test Images/lgl125 (465).png
# /kaggle/input/DataSet/Test Images/lg432 (48).png
# /kaggle/input/DataSet/Test Images/lg171 (192).png
# /kaggle/input/DataSet/Test Images/lg45 (529).png
# /kaggle/input/DataSet/Test Images/lg169 (46).png
# /kaggle/input/DataSet/Test Images/lg171 (375).png
# /kaggle/input/DataSet/Test Images/lgl125 (311).png
# /kaggle/input/DataSet/Test Images/lg45 (84).png
# /kaggle/input/DataSet/Test Images/lgl30 (104).png
# /kaggle/input/DataSet/Test Images/lg566 (444).png
# /kaggle/input/DataSet/Test Images/lg167 (28).png
# /kaggle/input/DataSet/Test Images/lgl60 (142).png
# /kaggle/input/DataSet/Test Images/lg99 (230).png
# /kaggle/input/DataSet/Test Images/lg168 (43).png
# /kaggle/input/DataSet/Test Images/lg432 (374).png
# /kaggle/input/DataSet/Test Images/lg168 (205).png
# /kaggle/input/DataSet/Test Images/lg432 (451).png
# /kaggle/input/DataSet/Test Images/lg169 (233).png
# /kaggle/input/DataSet/Test Images/lg171 (298).png
# /kaggle/input/DataSet/Test Images/lg566 (142).png
# /kaggle/input/DataSet/Test Images/lgl30 (1).png
# /kaggle/input/DataSet/Test Images/lgl 10 (54).png
# /kaggle/input/DataSet/Test Images/lg170 (40).png
# /kaggle/input/DataSet/Test Images/lg432 (118).png
# /kaggle/input/DataSet/Test Images/lgl85 (187).png
# /kaggle/input/DataSet/Test Images/lg566 (188).png
# /kaggle/input/DataSet/Test Images/lg45 (161).png
# /kaggle/input/DataSet/Test Images/lg56 (100).png
# /kaggle/input/DataSet/Test Images/lg87 (346).png
# /kaggle/input/DataSet/Test Images/lgl85 (217).png
# /kaggle/input/DataSet/Test Images/lg99 (101).png
# /kaggle/input/DataSet/Test Images/lg168 (17).png
# /kaggle/input/DataSet/Test Images/lgl85 (364).png
# /kaggle/input/DataSet/Test Images/lg170 (86).png
# /kaggle/input/DataSet/Test Images/lgl60 (44).png
# /kaggle/input/DataSet/Test Images/lg 988 (284).png
# /kaggle/input/DataSet/Test Images/lg898 (223).png
# /kaggle/input/DataSet/Test Images/lg898 (304).png
# /kaggle/input/DataSet/Test Images/lg898 (297).png
# /kaggle/input/DataSet/Test Images/lg171 (256).png
# /kaggle/input/DataSet/Test Images/lgl60 (101).png
# /kaggle/input/DataSet/Test Images/lg45 (120).png
# /kaggle/input/DataSet/Test Images/lg432 (448).png
# /kaggle/input/DataSet/Test Images/lgl85 (252).png
# /kaggle/input/DataSet/Test Images/lgl305 (225).png
# /kaggle/input/DataSet/Test Images/lg170 (188).png
# /kaggle/input/DataSet/Test Images/lgl125 (470).png
# /kaggle/input/DataSet/Test Images/lg171 (343).png
# /kaggle/input/DataSet/Test Images/lg99 (163).png
# /kaggle/input/DataSet/Test Images/lg87 (352).png
# /kaggle/input/DataSet/Test Images/lg 988 (71).png
# /kaggle/input/DataSet/Test Images/lg87 (317).png
# /kaggle/input/DataSet/Test Images/lg168 (268).png
# /kaggle/input/DataSet/Test Images/lg99 (212).png
# /kaggle/input/DataSet/Test Images/lgl125 (506).png
# /kaggle/input/DataSet/Test Images/lg167 (90).png
# /kaggle/input/DataSet/Test Images/lg170 (83).png
# /kaggle/input/DataSet/Test Images/lg171 (455).png
# /kaggle/input/DataSet/Test Images/lg432 (130).png
# /kaggle/input/DataSet/Test Images/lgl85 (3).png
# /kaggle/input/DataSet/Test Images/lg432 (370).png
# /kaggle/input/DataSet/Test Images/lgl125 (425).png
# /kaggle/input/DataSet/Test Images/lgl125 (143).png
# /kaggle/input/DataSet/Test Images/lg898 (111).png
# /kaggle/input/DataSet/Test Images/lg56 (284).png
# /kaggle/input/DataSet/Test Images/lg170 (177).png
# /kaggle/input/DataSet/Test Images/lg170 (23).png
# /kaggle/input/DataSet/Test Images/lg167 (48).png
# /kaggle/input/DataSet/Test Images/lg87 (217).png
# /kaggle/input/DataSet/Test Images/lg171 (306).png
# /kaggle/input/DataSet/Test Images/lg45 (397).png
# /kaggle/input/DataSet/Test Images/lgl30 (30).png
# /kaggle/input/DataSet/Test Images/lg171 (321).png
# /kaggle/input/DataSet/Test Images/lg432 (352).png
# /kaggle/input/DataSet/Test Images/lgl125 (233).png
# /kaggle/input/DataSet/Test Images/lg99 (36).png
# /kaggle/input/DataSet/Test Images/lg101 (100).png
# /kaggle/input/DataSet/Test Images/lgl60 (152).png
# /kaggle/input/DataSet/Test Images/lgl125 (56).png
# /kaggle/input/DataSet/Test Images/lgl85 (235).png
# /kaggle/input/DataSet/Test Images/lgl85 (487).png
# /kaggle/input/DataSet/Test Images/lg171 (436).png
# /kaggle/input/DataSet/Test Images/lg45 (241).png
# /kaggle/input/DataSet/Test Images/lgl125 (376).png
# /kaggle/input/DataSet/Test Images/lgl125 (230).png
# /kaggle/input/DataSet/Test Images/lg 988 (231).png
# /kaggle/input/DataSet/Test Images/lg898 (184).png
# /kaggle/input/DataSet/Test Images/lg167 (137).png
# /kaggle/input/DataSet/Test Images/lgl 10 (75).png
# /kaggle/input/DataSet/Test Images/lg171 (267).png
# /kaggle/input/DataSet/Test Images/lgl125 (101).png
# /kaggle/input/DataSet/Test Images/lgl85 (423).png
# /kaggle/input/DataSet/Test Images/lg169 (237).png
# /kaggle/input/DataSet/Test Images/lg898 (300).png
# /kaggle/input/DataSet/Test Images/lg171 (461).png
# /kaggle/input/DataSet/Test Images/lg432 (279).png
# /kaggle/input/DataSet/Test Images/lg87 (40).png
# /kaggle/input/DataSet/Test Images/lg169 (178).png
# /kaggle/input/DataSet/Test Images/lgl305 (168).png
# /kaggle/input/DataSet/Test Images/lg898 (144).png
# /kaggle/input/DataSet/Test Images/lg898 (225).png
# /kaggle/input/DataSet/Test Images/lg170 (182).png
# /kaggle/input/DataSet/Test Images/lgl305 (231).png
# /kaggle/input/DataSet/Test Images/lg168 (13).png
# /kaggle/input/DataSet/Test Images/lgl85 (121).png
# /kaggle/input/DataSet/Test Images/lgl85 (373).png
# /kaggle/input/DataSet/Test Images/lg56 (131).png
# /kaggle/input/DataSet/Test Images/lg45 (329).png
# /kaggle/input/DataSet/Test Images/lg76 (41).png
# /kaggle/input/DataSet/Test Images/lgl125 (186).png
# /kaggle/input/DataSet/Test Images/lg 988 (106).png
# /kaggle/input/DataSet/Test Images/lg432 (325).png
# /kaggle/input/DataSet/Test Images/lg56 (175).png
# /kaggle/input/DataSet/Test Images/lg99 (92).png
# /kaggle/input/DataSet/Test Images/lgl85 (46).png
# /kaggle/input/DataSet/Test Images/lg171 (40).png
# /kaggle/input/DataSet/Test Images/lg432 (29).png
# /kaggle/input/DataSet/Test Images/lgl125 (550).png
# /kaggle/input/DataSet/Test Images/lg87 (412).png
# /kaggle/input/DataSet/Test Images/lgl30 (44).png
# /kaggle/input/DataSet/Test Images/lg170 (56).png
# /kaggle/input/DataSet/Test Images/lg170 (112).png
# /kaggle/input/DataSet/Test Images/lgl125 (373).png
# /kaggle/input/DataSet/Test Images/lg566 (177).png
# /kaggle/input/DataSet/Test Images/lg432 (442).png
# /kaggle/input/DataSet/Test Images/lg99 (98).png
# /kaggle/input/DataSet/Test Images/lg45 (95).png
# /kaggle/input/DataSet/Test Images/lg170 (213).png
# /kaggle/input/DataSet/Test Images/lgl125 (539).png
# /kaggle/input/DataSet/Test Images/lgl305 (63).png
# /kaggle/input/DataSet/Test Images/lg171 (173).png
# /kaggle/input/DataSet/Test Images/lg169 (265).png
# /kaggle/input/DataSet/Test Images/lg56 (88).png
# /kaggle/input/DataSet/Test Images/lg45 (63).png
# /kaggle/input/DataSet/Test Images/lg170 (85).png
# /kaggle/input/DataSet/Test Images/lg566 (242).png
# /kaggle/input/DataSet/Test Images/lg566 (313).png
# /kaggle/input/DataSet/Test Images/lgl30 (18).png
# /kaggle/input/DataSet/Test Images/lgl125 (33).png
# /kaggle/input/DataSet/Test Images/lg101 (32).png
# /kaggle/input/DataSet/Test Images/lgl125 (11).png
# /kaggle/input/DataSet/Test Images/lg 988 (39).png
# /kaggle/input/DataSet/Test Images/lgl305 (177).png
# /kaggle/input/DataSet/Test Images/lgl305 (183).png
# /kaggle/input/DataSet/Test Images/lg45 (460).png
# /kaggle/input/DataSet/Test Images/lgl125 (405).png
# /kaggle/input/DataSet/Test Images/lg45 (50).png
# /kaggle/input/DataSet/Test Images/lg87 (295).png
# /kaggle/input/DataSet/Test Images/lg99 (281).png
# /kaggle/input/DataSet/Test Images/lgl125 (534).png
# /kaggle/input/DataSet/Test Images/lg 988 (11).png
# /kaggle/input/DataSet/Test Images/lg 988 (103).png
# /kaggle/input/DataSet/Test Images/lgl30 (23).png
# /kaggle/input/DataSet/Test Images/lg45 (456).png
# /kaggle/input/DataSet/Test Images/lg76 (132).png
# /kaggle/input/DataSet/Test Images/lgl85 (309).png
# /kaggle/input/DataSet/Test Images/lg76 (107).png
# /kaggle/input/DataSet/Test Images/lgl125 (535).png
# /kaggle/input/DataSet/Test Images/lg101 (314).png
# /kaggle/input/DataSet/Test Images/lg170 (39).png
# /kaggle/input/DataSet/Test Images/lgl305 (161).png
# /kaggle/input/DataSet/Test Images/lg56 (42).png
# /kaggle/input/DataSet/Test Images/lg101 (11).png
# /kaggle/input/DataSet/Test Images/lg101 (43).png
# /kaggle/input/DataSet/Test Images/lgl85 (79).png
# /kaggle/input/DataSet/Test Images/lg87 (390).png
# /kaggle/input/DataSet/Test Images/lg170 (172).png
# /kaggle/input/DataSet/Test Images/lg168 (75).png
# /kaggle/input/DataSet/Test Images/lg76 (6).png
# /kaggle/input/DataSet/Test Images/lg432 (76).png
# /kaggle/input/DataSet/Test Images/lg169 (213).png
# /kaggle/input/DataSet/Test Images/lg566 (13).png
# /kaggle/input/DataSet/Test Images/lg566 (176).png
# /kaggle/input/DataSet/Test Images/lgl85 (59).png
# /kaggle/input/DataSet/Test Images/lg101 (63).png
# /kaggle/input/DataSet/Test Images/lg76 (94).png
# /kaggle/input/DataSet/Test Images/lg87 (17).png
# /kaggle/input/DataSet/Test Images/lg566 (82).png
# /kaggle/input/DataSet/Test Images/lg 988 (204).png
# /kaggle/input/DataSet/Test Images/lg167 (151).png
# /kaggle/input/DataSet/Test Images/lg87 (274).png
# /kaggle/input/DataSet/Test Images/lg 988 (353).png
# /kaggle/input/DataSet/Test Images/lg167 (153).png
# /kaggle/input/DataSet/Test Images/lg171 (178).png
# /kaggle/input/DataSet/Test Images/lg99 (24).png
# /kaggle/input/DataSet/Test Images/lg566 (160).png
# /kaggle/input/DataSet/Test Images/lg87 (453).png
# /kaggle/input/DataSet/Test Images/lgl125 (446).png
# /kaggle/input/DataSet/Test Images/lg168 (108).png
# /kaggle/input/DataSet/Test Images/lg171 (134).png
# /kaggle/input/DataSet/Test Images/lgl85 (51).png
# /kaggle/input/DataSet/Test Images/lg45 (274).png
# /kaggle/input/DataSet/Test Images/lg101 (191).png
# /kaggle/input/DataSet/Test Images/lg45 (316).png
# /kaggle/input/DataSet/Test Images/lg101 (291).png
# /kaggle/input/DataSet/Test Images/lgl125 (300).png
# /kaggle/input/DataSet/Test Images/lg76 (164).png
# /kaggle/input/DataSet/Test Images/lg168 (167).png
# /kaggle/input/DataSet/Test Images/lg56 (259).png
# /kaggle/input/DataSet/Test Images/lg56 (283).png
# /kaggle/input/DataSet/Test Images/lgl60 (145).png
# /kaggle/input/DataSet/Test Images/lg171 (294).png
# /kaggle/input/DataSet/Test Images/lg 988 (383).png
# /kaggle/input/DataSet/Test Images/lg432 (407).png
# /kaggle/input/DataSet/Test Images/lgl125 (75).png
# /kaggle/input/DataSet/Test Images/lg167 (145).png
# /kaggle/input/DataSet/Test Images/lg898 (199).png
# /kaggle/input/DataSet/Test Images/lg167 (25).png
# /kaggle/input/DataSet/Test Images/lg87 (329).png
# /kaggle/input/DataSet/Test Images/lgl85 (521).png
# /kaggle/input/DataSet/Test Images/lgl305 (126).png
# /kaggle/input/DataSet/Test Images/lg56 (110).png
# /kaggle/input/DataSet/Test Images/lg76 (33).png
# /kaggle/input/DataSet/Test Images/lg99 (286).png
# /kaggle/input/DataSet/Test Images/lgl60 (267).png
# /kaggle/input/DataSet/Test Images/lg99 (190).png
# /kaggle/input/DataSet/Test Images/lg432 (389).png
# /kaggle/input/DataSet/Test Images/lg87 (200).png
# /kaggle/input/DataSet/Test Images/lg56 (85).png
# /kaggle/input/DataSet/Test Images/lg566 (28).png
# /kaggle/input/DataSet/Test Images/lgl 10 (77).png
# /kaggle/input/DataSet/Test Images/lg898 (316).png
# /kaggle/input/DataSet/Test Images/lgl125 (40).png
# /kaggle/input/DataSet/Test Images/lg432 (227).png
# /kaggle/input/DataSet/Test Images/lg99 (127).png
# /kaggle/input/DataSet/Test Images/lg101 (229).png
# /kaggle/input/DataSet/Test Images/lg 988 (72).png
# /kaggle/input/DataSet/Test Images/lg171 (492).png
# /kaggle/input/DataSet/Test Images/lgl60 (301).png
# /kaggle/input/DataSet/Test Images/lg898 (215).png
# /kaggle/input/DataSet/Test Images/lg87 (137).png
# /kaggle/input/DataSet/Test Images/lgl125 (462).png
# /kaggle/input/DataSet/Test Images/lg56 (81).png
# /kaggle/input/DataSet/Test Images/lg 988 (258).png
# /kaggle/input/DataSet/Test Images/lg432 (349).png
# /kaggle/input/DataSet/Test Images/lg99 (249).png
# /kaggle/input/DataSet/Test Images/lgl 10 (89).png
# /kaggle/input/DataSet/Test Images/lgl125 (538).png
# /kaggle/input/DataSet/Test Images/lgl85 (520).png
# /kaggle/input/DataSet/Test Images/lgl305 (88).png
# /kaggle/input/DataSet/Test Images/lg170 (183).png
# /kaggle/input/DataSet/Test Images/lgl85 (8).png
# /kaggle/input/DataSet/Test Images/lg432 (396).png
# /kaggle/input/DataSet/Test Images/lg45 (349).png
# /kaggle/input/DataSet/Test Images/lg45 (324).png
# /kaggle/input/DataSet/Test Images/lg898 (87).png
# /kaggle/input/DataSet/Test Images/lg171 (339).png
# /kaggle/input/DataSet/Test Images/lgl125 (218).png
# /kaggle/input/DataSet/Test Images/lg171 (457).png
# /kaggle/input/DataSet/Test Images/lg432 (491).png
# /kaggle/input/DataSet/Test Images/lgl125 (413).png
# /kaggle/input/DataSet/Test Images/lgl85 (338).png
# /kaggle/input/DataSet/Test Images/lg101 (137).png
# /kaggle/input/DataSet/Test Images/lg99 (151).png
# /kaggle/input/DataSet/Test Images/lg566 (308).png
# /kaggle/input/DataSet/Test Images/lg898 (97).png
# /kaggle/input/DataSet/Test Images/lg 988 (54).png
# /kaggle/input/DataSet/Test Images/lgl125 (528).png
# /kaggle/input/DataSet/Test Images/lg101 (25).png
# /kaggle/input/DataSet/Test Images/lgl125 (502).png
# /kaggle/input/DataSet/Test Images/lg167 (93).png
# /kaggle/input/DataSet/Test Images/lg170 (95).png
# /kaggle/input/DataSet/Test Images/lg87 (208).png
# /kaggle/input/DataSet/Test Images/lgl305 (222).png
# /kaggle/input/DataSet/Test Images/lg566 (431).png
# /kaggle/input/DataSet/Test Images/lg167 (83).png
# /kaggle/input/DataSet/Test Images/lg432 (200).png
# /kaggle/input/DataSet/Test Images/lg171 (70).png
# /kaggle/input/DataSet/Test Images/lgl85 (85).png
# /kaggle/input/DataSet/Test Images/lg566 (205).png
# /kaggle/input/DataSet/Test Images/lg432 (269).png
# /kaggle/input/DataSet/Test Images/lgl60 (91).png
# /kaggle/input/DataSet/Test Images/lg566 (239).png
# /kaggle/input/DataSet/Test Images/lgl60 (265).png
# /kaggle/input/DataSet/Test Images/lg87 (344).png
# /kaggle/input/DataSet/Test Images/lgl125 (480).png
# /kaggle/input/DataSet/Test Images/lg 988 (59).png
# /kaggle/input/DataSet/Test Images/lg432 (121).png
# /kaggle/input/DataSet/Test Images/lg566 (7).png
# /kaggle/input/DataSet/Test Images/lgl125 (296).png
# /kaggle/input/DataSet/Test Images/lg171 (57).png
# /kaggle/input/DataSet/Test Images/lg76 (9).png
# /kaggle/input/DataSet/Test Images/lg898 (221).png
# /kaggle/input/DataSet/Test Images/lg45 (517).png
# /kaggle/input/DataSet/Test Images/lgl85 (11).png
# /kaggle/input/DataSet/Test Images/lgl60 (27).png
# /kaggle/input/DataSet/Test Images/lg45 (393).png
# /kaggle/input/DataSet/Test Images/lg87 (345).png
# /kaggle/input/DataSet/Test Images/lg432 (291).png
# /kaggle/input/DataSet/Test Images/lg168 (230).png
# /kaggle/input/DataSet/Test Images/lgl305 (3).png
# /kaggle/input/DataSet/Test Images/lgl60 (189).png
# /kaggle/input/DataSet/Test Images/lgl85 (152).png
# /kaggle/input/DataSet/Test Images/lg171 (183).png
# /kaggle/input/DataSet/Test Images/lgl60 (88).png
# /kaggle/input/DataSet/Test Images/lg171 (382).png
# /kaggle/input/DataSet/Test Images/lg45 (130).png
# /kaggle/input/DataSet/Test Images/lg171 (137).png
# /kaggle/input/DataSet/Test Images/lg 988 (110).png
# /kaggle/input/DataSet/Test Images/lg 988 (163).png
# /kaggle/input/DataSet/Test Images/lg56 (65).png
# /kaggle/input/DataSet/Test Images/lg56 (98).png
# /kaggle/input/DataSet/Test Images/lg56 (255).png
# /kaggle/input/DataSet/Test Images/lgl125 (207).png
# /kaggle/input/DataSet/Test Images/lg45 (345).png
# /kaggle/input/DataSet/Test Images/lg56 (134).png
# /kaggle/input/DataSet/Test Images/lg168 (286).png
# /kaggle/input/DataSet/Test Images/lgl60 (158).png
# /kaggle/input/DataSet/Test Images/lgl125 (220).png
# /kaggle/input/DataSet/Test Images/lgl305 (220).png
# /kaggle/input/DataSet/Test Images/lgl60 (240).png
# /kaggle/input/DataSet/Test Images/lg56 (223).png
# /kaggle/input/DataSet/Test Images/lg170 (201).png
# /kaggle/input/DataSet/Test Images/lg432 (417).png
# /kaggle/input/DataSet/Test Images/lg170 (14).png
# /kaggle/input/DataSet/Test Images/lg432 (52).png
# /kaggle/input/DataSet/Test Images/lg168 (424).png
# /kaggle/input/DataSet/Test Images/lg171 (444).png
# /kaggle/input/DataSet/Test Images/lg45 (59).png
# /kaggle/input/DataSet/Test Images/lg169 (96).png
# /kaggle/input/DataSet/Test Images/lgl305 (237).png
# /kaggle/input/DataSet/Test Images/lg76 (135).png
# /kaggle/input/DataSet/Test Images/lgl305 (6).png
# /kaggle/input/DataSet/Test Images/lg432 (318).png
# /kaggle/input/DataSet/Test Images/lg171 (149).png
# /kaggle/input/DataSet/Test Images/lgl305 (197).png
# /kaggle/input/DataSet/Test Images/lgl30 (52).png
# /kaggle/input/DataSet/Test Images/lg 988 (285).png
# /kaggle/input/DataSet/Test Images/lg101 (145).png
# /kaggle/input/DataSet/Test Images/lg432 (348).png
# /kaggle/input/DataSet/Test Images/lg87 (237).png
# /kaggle/input/DataSet/Test Images/lg170 (175).png
# /kaggle/input/DataSet/Test Images/lg87 (19).png
# /kaggle/input/DataSet/Test Images/lg432 (137).png
# /kaggle/input/DataSet/Test Images/lg56 (25).png
# /kaggle/input/DataSet/Test Images/lg99 (134).png
# /kaggle/input/DataSet/Test Images/lg170 (189).png
# /kaggle/input/DataSet/Test Images/lg898 (64).png
# /kaggle/input/DataSet/Test Images/lg99 (49).png
# /kaggle/input/DataSet/Test Images/lg169 (109).png
# /kaggle/input/DataSet/Test Images/lg171 (45).png
# /kaggle/input/DataSet/Test Images/lg898 (6).png
# /kaggle/input/DataSet/Test Images/lgl85 (430).png
# /kaggle/input/DataSet/Test Images/lg170 (244).png
# /kaggle/input/DataSet/Test Images/lgl 10 (34).png
# /kaggle/input/DataSet/Test Images/lg171 (261).png
# /kaggle/input/DataSet/Test Images/lg566 (25).png
# /kaggle/input/DataSet/Test Images/lgl125 (452).png
# /kaggle/input/DataSet/Test Images/lg168 (172).png
# /kaggle/input/DataSet/Test Images/lg169 (256).png
# /kaggle/input/DataSet/Test Images/lg898 (76).png
# /kaggle/input/DataSet/Test Images/lg168 (211).png
# /kaggle/input/DataSet/Test Images/lg45 (212).png
# /kaggle/input/DataSet/Test Images/lgl85 (199).png
# /kaggle/input/DataSet/Test Images/lg56 (260).png
# /kaggle/input/DataSet/Test Images/lg76 (121).png
# /kaggle/input/DataSet/Test Images/lg 988 (370).png
# /kaggle/input/DataSet/Test Images/lg 988 (334).png
# /kaggle/input/DataSet/Test Images/lg45 (209).png
# /kaggle/input/DataSet/Test Images/lg167 (42).png
# /kaggle/input/DataSet/Test Images/lg432 (221).png
# /kaggle/input/DataSet/Test Images/lgl85 (233).png
# /kaggle/input/DataSet/Test Images/lg76 (37).png
# /kaggle/input/DataSet/Test Images/lgl 10 (91).png
# /kaggle/input/DataSet/Test Images/lg566 (262).png
# /kaggle/input/DataSet/Test Images/lg99 (185).png
# /kaggle/input/DataSet/Test Images/lg 988 (187).png
# /kaggle/input/DataSet/Test Images/lg45 (165).png
# /kaggle/input/DataSet/Test Images/lg56 (230).png
# /kaggle/input/DataSet/Test Images/lg171 (247).png
# /kaggle/input/DataSet/Test Images/lgl305 (4).png
# /kaggle/input/DataSet/Test Images/lg45 (470).png
# /kaggle/input/DataSet/Test Images/lg171 (229).png
# /kaggle/input/DataSet/Test Images/lgl60 (49).png
# /kaggle/input/DataSet/Test Images/lg566 (215).png
# /kaggle/input/DataSet/Test Images/lg171 (130).png
# /kaggle/input/DataSet/Test Images/lg 988 (243).png
# /kaggle/input/DataSet/Test Images/lg99 (241).png
# /kaggle/input/DataSet/Test Images/lgl305 (190).png
# /kaggle/input/DataSet/Test Images/lg101 (84).png
# /kaggle/input/DataSet/Test Images/lg87 (261).png
# /kaggle/input/DataSet/Test Images/lg87 (170).png
# /kaggle/input/DataSet/Test Images/lg432 (254).png
# /kaggle/input/DataSet/Test Images/lg432 (278).png
# /kaggle/input/DataSet/Test Images/lg87 (417).png
# /kaggle/input/DataSet/Test Images/lgl125 (281).png
# /kaggle/input/DataSet/Test Images/lg566 (451).png
# /kaggle/input/DataSet/Test Images/lgl305 (58).png
# /kaggle/input/DataSet/Test Images/lg168 (127).png
# /kaggle/input/DataSet/Test Images/lg171 (430).png
# /kaggle/input/DataSet/Test Images/lgl305 (239).png
# /kaggle/input/DataSet/Test Images/lg87 (267).png
# /kaggle/input/DataSet/Test Images/lg898 (78).png
# /kaggle/input/DataSet/Test Images/lg432 (274).png
# /kaggle/input/DataSet/Test Images/lg171 (17).png
# /kaggle/input/DataSet/Test Images/lg101 (165).png
# /kaggle/input/DataSet/Test Images/lg171 (14).png
# /kaggle/input/DataSet/Test Images/lg432 (75).png
# /kaggle/input/DataSet/Test Images/lg87 (159).png
# /kaggle/input/DataSet/Test Images/lg566 (11).png
# /kaggle/input/DataSet/Test Images/lg99 (3).png
# /kaggle/input/DataSet/Test Images/lg566 (403).png
# /kaggle/input/DataSet/Test Images/lg171 (381).png
# /kaggle/input/DataSet/Test Images/lg101 (70).png
# /kaggle/input/DataSet/Test Images/lg169 (191).png
# /kaggle/input/DataSet/Test Images/lg76 (175).png
# /kaggle/input/DataSet/Test Images/lgl85 (70).png
# /kaggle/input/DataSet/Test Images/lg167 (51).png
# /kaggle/input/DataSet/Test Images/lgl125 (428).png
# /kaggle/input/DataSet/Test Images/lg898 (45).png
# /kaggle/input/DataSet/Test Images/lg566 (371).png
# /kaggle/input/DataSet/Test Images/lg432 (77).png
# /kaggle/input/DataSet/Test Images/lg101 (285).png
# /kaggle/input/DataSet/Test Images/lg171 (481).png
# /kaggle/input/DataSet/Test Images/lg101 (290).png
# /kaggle/input/DataSet/Test Images/lg168 (65).png
# /kaggle/input/DataSet/Test Images/lgl60 (11).png
# /kaggle/input/DataSet/Test Images/lg167 (32).png
# /kaggle/input/DataSet/Test Images/lg169 (61).png
# /kaggle/input/DataSet/Test Images/lgl85 (308).png
# /kaggle/input/DataSet/Test Images/lg170 (51).png
# /kaggle/input/DataSet/Test Images/lg45 (243).png
# /kaggle/input/DataSet/Test Images/lg99 (197).png
# /kaggle/input/DataSet/Test Images/lg45 (469).png
# /kaggle/input/DataSet/Test Images/lg169 (33).png
# /kaggle/input/DataSet/Test Images/lg566 (209).png
# /kaggle/input/DataSet/Test Images/lgl85 (352).png
# /kaggle/input/DataSet/Test Images/lg56 (104).png
# /kaggle/input/DataSet/Test Images/lg168 (139).png
# /kaggle/input/DataSet/Test Images/lgl305 (57).png
# /kaggle/input/DataSet/Test Images/lg101 (299).png
# /kaggle/input/DataSet/Test Images/lg168 (224).png
# /kaggle/input/DataSet/Test Images/lg101 (189).png
# /kaggle/input/DataSet/Test Images/lg 988 (178).png
# /kaggle/input/DataSet/Test Images/lg45 (283).png
# /kaggle/input/DataSet/Test Images/lgl85 (256).png
# /kaggle/input/DataSet/Test Images/lg169 (171).png
# /kaggle/input/DataSet/Test Images/lgl60 (283).png
# /kaggle/input/DataSet/Test Images/lg898 (252).png
# /kaggle/input/DataSet/Test Images/lg45 (238).png
# /kaggle/input/DataSet/Test Images/lg56 (9).png
# /kaggle/input/DataSet/Test Images/lg 988 (81).png
# /kaggle/input/DataSet/Test Images/lg99 (9).png
# /kaggle/input/DataSet/Test Images/lg566 (103).png
# /kaggle/input/DataSet/Test Images/lg566 (168).png
# /kaggle/input/DataSet/Test Images/lg87 (347).png
# /kaggle/input/DataSet/Test Images/lg45 (97).png
# /kaggle/input/DataSet/Test Images/lg76 (27).png
# /kaggle/input/DataSet/Test Images/lgl125 (504).png
# /kaggle/input/DataSet/Test Images/lg 988 (73).png
# /kaggle/input/DataSet/Test Images/lg101 (49).png
# /kaggle/input/DataSet/Test Images/lg168 (381).png
# /kaggle/input/DataSet/Test Images/lg898 (147).png
# /kaggle/input/DataSet/Test Images/lgl85 (448).png
# /kaggle/input/DataSet/Test Images/lg566 (245).png
# /kaggle/input/DataSet/Test Images/lg45 (114).png
# /kaggle/input/DataSet/Test Images/lg 988 (237).png
# /kaggle/input/DataSet/Test Images/lgl60 (82).png
# /kaggle/input/DataSet/Test Images/lg 988 (234).png
# /kaggle/input/DataSet/Test Images/lg566 (150).png
# /kaggle/input/DataSet/Test Images/lg898 (157).png
# /kaggle/input/DataSet/Test Images/lg 988 (369).png
# /kaggle/input/DataSet/Test Images/lgl 10 (111).png
# /kaggle/input/DataSet/Test Images/lg87 (264).png
# /kaggle/input/DataSet/Test Images/lg87 (225).png
# /kaggle/input/DataSet/Test Images/lgl305 (105).png
# /kaggle/input/DataSet/Test Images/lg168 (158).png
# /kaggle/input/DataSet/Test Images/lgl125 (484).png
# /kaggle/input/DataSet/Test Images/lg101 (153).png
# /kaggle/input/DataSet/Test Images/lg99 (206).png
# /kaggle/input/DataSet/Test Images/lg898 (251).png
# /kaggle/input/DataSet/Test Images/lgl85 (444).png
# /kaggle/input/DataSet/Test Images/lg171 (190).png
# /kaggle/input/DataSet/Test Images/lg99 (177).png
# /kaggle/input/DataSet/Test Images/lg169 (116).png
# /kaggle/input/DataSet/Test Images/lg76 (86).png
# /kaggle/input/DataSet/Test Images/lg432 (191).png
# /kaggle/input/DataSet/Test Images/lgl305 (40).png
# /kaggle/input/DataSet/Test Images/lg99 (307).png
# /kaggle/input/DataSet/Test Images/lgl305 (215).png
# /kaggle/input/DataSet/Test Images/lgl60 (187).png
# /kaggle/input/DataSet/Test Images/lg99 (135).png
# /kaggle/input/DataSet/Test Images/lg 988 (5).png
# /kaggle/input/DataSet/Test Images/lg87 (341).png
# /kaggle/input/DataSet/Test Images/lg101 (218).png
# /kaggle/input/DataSet/Test Images/lg167 (65).png
# /kaggle/input/DataSet/Test Images/lg87 (407).png
# /kaggle/input/DataSet/Test Images/lg76 (182).png
# /kaggle/input/DataSet/Test Images/lg169 (267).png
# /kaggle/input/DataSet/Test Images/lg898 (273).png
# /kaggle/input/DataSet/Test Images/lg432 (440).png
# /kaggle/input/DataSet/Test Images/lg56 (154).png
# /kaggle/input/DataSet/Test Images/lg99 (211).png
# /kaggle/input/DataSet/Test Images/lg566 (8).png
# /kaggle/input/DataSet/Test Images/lg56 (190).png
# /kaggle/input/DataSet/Test Images/lg170 (122).png
# /kaggle/input/DataSet/Test Images/lg99 (178).png
# /kaggle/input/DataSet/Test Images/lg898 (138).png
# /kaggle/input/DataSet/Test Images/lg169 (5).png
# /kaggle/input/DataSet/Test Images/lg 988 (232).png
# /kaggle/input/DataSet/Test Images/lg566 (126).png
# /kaggle/input/DataSet/Test Images/lg432 (181).png
# /kaggle/input/DataSet/Test Images/lg566 (284).png
# /kaggle/input/DataSet/Test Images/lg101 (55).png
# /kaggle/input/DataSet/Test Images/lg566 (438).png
# /kaggle/input/DataSet/Test Images/lg171 (301).png
# /kaggle/input/DataSet/Test Images/lg76 (133).png
# /kaggle/input/DataSet/Test Images/lg101 (323).png
# /kaggle/input/DataSet/Test Images/lg76 (151).png
# /kaggle/input/DataSet/Test Images/lgl305 (24).png
# /kaggle/input/DataSet/Test Images/lg56 (212).png
# /kaggle/input/DataSet/Test Images/lg 988 (188).png
# /kaggle/input/DataSet/Test Images/lg101 (29).png
# /kaggle/input/DataSet/Test Images/lg45 (524).png
# /kaggle/input/DataSet/Test Images/lg76 (176).png
# /kaggle/input/DataSet/Test Images/lg898 (287).png
# /kaggle/input/DataSet/Test Images/lgl305 (54).png
# /kaggle/input/DataSet/Test Images/lgl85 (278).png
# /kaggle/input/DataSet/Test Images/lg169 (217).png
# /kaggle/input/DataSet/Test Images/lgl60 (180).png
# /kaggle/input/DataSet/Test Images/lg898 (102).png
# /kaggle/input/DataSet/Test Images/lg 988 (212).png
# /kaggle/input/DataSet/Test Images/lg45 (431).png
# /kaggle/input/DataSet/Test Images/lgl60 (310).png
# /kaggle/input/DataSet/Test Images/lg45 (111).png
# /kaggle/input/DataSet/Test Images/lgl85 (271).png
# /kaggle/input/DataSet/Test Images/lg432 (207).png
# /kaggle/input/DataSet/Test Images/lg168 (253).png
# /kaggle/input/DataSet/Test Images/lg101 (102).png
# /kaggle/input/DataSet/Test Images/lg76 (112).png
# /kaggle/input/DataSet/Test Images/lgl125 (209).png
# /kaggle/input/DataSet/Test Images/lg76 (189).png
# /kaggle/input/DataSet/Test Images/lgl85 (239).png
# /kaggle/input/DataSet/Test Images/lg898 (10).png
# /kaggle/input/DataSet/Test Images/lgl85 (295).png
# /kaggle/input/DataSet/Test Images/lgl125 (319).png
# /kaggle/input/DataSet/Test Images/lg566 (201).png
# /kaggle/input/DataSet/Test Images/lg566 (283).png
# /kaggle/input/DataSet/Test Images/lg56 (224).png
# /kaggle/input/DataSet/Test Images/lg45 (227).png
# /kaggle/input/DataSet/Test Images/lg168 (150).png
# /kaggle/input/DataSet/Test Images/lg99 (244).png
# /kaggle/input/DataSet/Test Images/lg56 (246).png
# /kaggle/input/DataSet/Test Images/lg566 (227).png
# /kaggle/input/DataSet/Test Images/lg168 (20).png
# /kaggle/input/DataSet/Test Images/lg566 (45).png
# /kaggle/input/DataSet/Test Images/lg432 (96).png
# /kaggle/input/DataSet/Test Images/lg898 (5).png
# /kaggle/input/DataSet/Test Images/lg101 (103).png
# /kaggle/input/DataSet/Test Images/lg432 (494).png
# /kaggle/input/DataSet/Test Images/lg170 (78).png
# /kaggle/input/DataSet/Test Images/lg 988 (254).png
# /kaggle/input/DataSet/Test Images/lg170 (48).png
# /kaggle/input/DataSet/Test Images/lg99 (10).png
# /kaggle/input/DataSet/Test Images/lg76 (7).png
# /kaggle/input/DataSet/Test Images/lg171 (205).png
# /kaggle/input/DataSet/Test Images/lg432 (419).png
# /kaggle/input/DataSet/Test Images/lg171 (19).png
# /kaggle/input/DataSet/Test Images/lg87 (215).png
# /kaggle/input/DataSet/Test Images/lg169 (144).png
# /kaggle/input/DataSet/Test Images/lg898 (336).png
# /kaggle/input/DataSet/Test Images/lg432 (80).png
# /kaggle/input/DataSet/Test Images/lg45 (392).png
# /kaggle/input/DataSet/Test Images/lg99 (130).png
# /kaggle/input/DataSet/Test Images/lgl85 (118).png
# /kaggle/input/DataSet/Test Images/lg898 (291).png
# /kaggle/input/DataSet/Test Images/lg432 (460).png
# /kaggle/input/DataSet/Test Images/lg167 (23).png
# /kaggle/input/DataSet/Test Images/lg 988 (173).png
# /kaggle/input/DataSet/Test Images/lg168 (277).png
# /kaggle/input/DataSet/Test Images/lg 988 (131).png
# /kaggle/input/DataSet/Test Images/lgl125 (58).png
# /kaggle/input/DataSet/Test Images/lg101 (227).png
# /kaggle/input/DataSet/Test Images/lg432 (346).png
# /kaggle/input/DataSet/Test Images/lgl85 (405).png
# /kaggle/input/DataSet/Test Images/lgl60 (205).png
# /kaggle/input/DataSet/Test Images/lgl85 (331).png
# /kaggle/input/DataSet/Test Images/lg45 (423).png
# /kaggle/input/DataSet/Test Images/lgl60 (70).png
# /kaggle/input/DataSet/Test Images/lg168 (145).png
# /kaggle/input/DataSet/Test Images/lg566 (374).png
# /kaggle/input/DataSet/Test Images/lg168 (231).png
# /kaggle/input/DataSet/Test Images/lg45 (341).png
# /kaggle/input/DataSet/Test Images/lg45 (309).png
# /kaggle/input/DataSet/Test Images/lg56 (148).png
# /kaggle/input/DataSet/Test Images/lg566 (107).png
# /kaggle/input/DataSet/Test Images/lgl125 (518).png
# /kaggle/input/DataSet/Test Images/lg566 (241).png
# /kaggle/input/DataSet/Test Images/lg168 (80).png
# /kaggle/input/DataSet/Test Images/lg45 (112).png
# /kaggle/input/DataSet/Test Images/lg45 (218).png
# /kaggle/input/DataSet/Test Images/lg566 (58).png
# /kaggle/input/DataSet/Test Images/lg898 (19).png
# /kaggle/input/DataSet/Test Images/lg432 (104).png
# /kaggle/input/DataSet/Test Images/lg99 (8).png
# /kaggle/input/DataSet/Test Images/lg56 (240).png
# /kaggle/input/DataSet/Test Images/lgl125 (265).png
# /kaggle/input/DataSet/Test Images/lg167 (86).png
# /kaggle/input/DataSet/Test Images/lgl60 (156).png
# /kaggle/input/DataSet/Test Images/lgl125 (536).png
# /kaggle/input/DataSet/Test Images/lg566 (439).png
# /kaggle/input/DataSet/Test Images/lgl125 (263).png
# /kaggle/input/DataSet/Test Images/lg99 (303).png
# /kaggle/input/DataSet/Test Images/lgl85 (180).png
# /kaggle/input/DataSet/Test Images/lgl305 (112).png
# /kaggle/input/DataSet/Test Images/lg432 (361).png
# /kaggle/input/DataSet/Test Images/lgl85 (247).png
# /kaggle/input/DataSet/Test Images/lgl305 (209).png
# /kaggle/input/DataSet/Test Images/lg87 (231).png
# /kaggle/input/DataSet/Test Images/lg45 (531).png
# /kaggle/input/DataSet/Test Images/lg99 (314).png
# /kaggle/input/DataSet/Test Images/lg168 (107).png
# /kaggle/input/DataSet/Test Images/lg167 (132).png
# /kaggle/input/DataSet/Test Images/lg76 (97).png
# /kaggle/input/DataSet/Test Images/lg101 (248).png
# /kaggle/input/DataSet/Test Images/lg101 (88).png
# /kaggle/input/DataSet/Test Images/lg45 (237).png
# ...
# /kaggle/input/DataSet/Train Images/ground2883.png
# /kaggle/input/DataSet/Train Images/ground0238.png
# /kaggle/input/DataSet/Train Images/ground4582.png
# /kaggle/input/DataSet/Train Images/ground1575.png
# /kaggle/input/DataSet/Train Images/ground5873.png
# /kaggle/input/DataSet/Train Images/clean3262.png
# /kaggle/input/DataSet/Train Images/ground4096.png
# /kaggle/input/DataSet/Train Images/clean3505.png
# /kaggle/input/DataSet/Train Images/ground2443.png
# /kaggle/input/DataSet/Train Images/clean1363.png
# /kaggle/input/DataSet/Train Images/clean2633.png
# /kaggle/input/DataSet/Train Images/clean4174.png
# /kaggle/input/DataSet/Train Images/ground4484.png
# /kaggle/input/DataSet/Train Images/clean0875.png
# /kaggle/input/DataSet/Train Images/ground0613.png
# /kaggle/input/DataSet/Train Images/clean3629.png
# /kaggle/input/DataSet/Train Images/ground0734.png
# /kaggle/input/DataSet/Train Images/ground2280.png
# /kaggle/input/DataSet/Train Images/ground2352.png
# /kaggle/input/DataSet/Train Images/clean0249.png
# /kaggle/input/DataSet/Train Images/clean0680.png
# /kaggle/input/DataSet/Train Images/ground1169.png
# /kaggle/input/DataSet/Train Images/clean4300.png
# /kaggle/input/DataSet/Train Images/clean3164.png
# /kaggle/input/DataSet/Train Images/clean5078.png
# /kaggle/input/DataSet/Train Images/clean5959.png
# /kaggle/input/DataSet/Train Images/ground0188.png
# /kaggle/input/DataSet/Train Images/ground1210.png
# /kaggle/input/DataSet/Train Images/clean0589.png
# /kaggle/input/DataSet/Train Images/ground3379.png
# /kaggle/input/DataSet/Train Images/clean0387.png
# /kaggle/input/DataSet/Train Images/ground1522.png
# /kaggle/input/DataSet/Train Images/ground0615.png
# /kaggle/input/DataSet/Train Images/ground2803.png
# /kaggle/input/DataSet/Train Images/ground3840.png
# /kaggle/input/DataSet/Train Images/ground0395.png
# /kaggle/input/DataSet/Train Images/clean5929.png
# /kaggle/input/DataSet/Train Images/ground0823.png
# /kaggle/input/DataSet/Train Images/ground5905.png
# /kaggle/input/DataSet/Train Images/ground4576.png
# /kaggle/input/DataSet/Train Images/ground0402.png
# /kaggle/input/DataSet/Train Images/clean2743.png
# /kaggle/input/DataSet/Train Images/clean4962.png
# /kaggle/input/DataSet/Train Images/ground1465.png
# /kaggle/input/DataSet/Train Images/ground4124.png
# /kaggle/input/DataSet/Train Images/ground2921.png
# /kaggle/input/DataSet/Train Images/clean4602.png
# /kaggle/input/DataSet/Train Images/ground2382.png
# /kaggle/input/DataSet/Train Images/ground0335.png
# /kaggle/input/DataSet/Train Images/clean0080.png
# /kaggle/input/DataSet/Train Images/clean4482.png
# /kaggle/input/DataSet/Train Images/ground4618.png
# /kaggle/input/DataSet/Train Images/ground2491.png
# /kaggle/input/DataSet/Train Images/clean0648.png
# /kaggle/input/DataSet/Train Images/clean0043.png
# /kaggle/input/DataSet/Train Images/ground4032.png
# /kaggle/input/DataSet/Train Images/clean1119.png
# /kaggle/input/DataSet/Train Images/clean1067.png
# /kaggle/input/DataSet/Train Images/clean1782.png
# /kaggle/input/DataSet/Train Images/clean3137.png
# /kaggle/input/DataSet/Train Images/ground0585.png
# /kaggle/input/DataSet/Train Images/clean2354.png
# /kaggle/input/DataSet/Train Images/clean0462.png
# /kaggle/input/DataSet/Train Images/ground2210.png
# /kaggle/input/DataSet/Train Images/clean1943.png
# /kaggle/input/DataSet/Train Images/clean4176.png
# /kaggle/input/DataSet/Train Images/ground2588.png
# /kaggle/input/DataSet/Train Images/ground0328.png
# /kaggle/input/DataSet/Train Images/ground4449.png
# /kaggle/input/DataSet/Train Images/clean4936.png
# /kaggle/input/DataSet/Train Images/clean4103.png
# /kaggle/input/DataSet/Train Images/ground0313.png
# /kaggle/input/DataSet/Train Images/clean2145.png
# /kaggle/input/DataSet/Train Images/ground2735.png
# /kaggle/input/DataSet/Train Images/ground5297.png
# /kaggle/input/DataSet/Train Images/ground5226.png
# /kaggle/input/DataSet/Train Images/clean4309.png
# /kaggle/input/DataSet/Train Images/clean0783.png
# /kaggle/input/DataSet/Train Images/ground3705.png
# /kaggle/input/DataSet/Train Images/ground0956.png
# /kaggle/input/DataSet/Train Images/clean4964.png
# /kaggle/input/DataSet/Train Images/clean0052.png
# /kaggle/input/DataSet/Train Images/ground0201.png
# /kaggle/input/DataSet/Train Images/ground2130.png
# /kaggle/input/DataSet/Train Images/clean3876.png
# /kaggle/input/DataSet/Train Images/ground3055.png
# /kaggle/input/DataSet/Train Images/ground2600.png
# /kaggle/input/DataSet/Train Images/ground1074.png
# /kaggle/input/DataSet/Train Images/ground0156.png
# /kaggle/input/DataSet/Train Images/clean3384.png
# /kaggle/input/DataSet/Train Images/ground5567.png
# /kaggle/input/DataSet/Train Images/clean2411.png
# /kaggle/input/DataSet/Train Images/clean3358.png
# /kaggle/input/DataSet/Train Images/ground5048.png
# /kaggle/input/DataSet/Train Images/ground2525.png
# /kaggle/input/DataSet/Train Images/ground1174.png
# /kaggle/input/DataSet/Train Images/clean3452.png
# /kaggle/input/DataSet/Train Images/ground0986.png
# /kaggle/input/DataSet/Train Images/ground0814.png
# /kaggle/input/DataSet/Train Images/ground3288.png
# /kaggle/input/DataSet/Train Images/ground2789.png
# /kaggle/input/DataSet/Train Images/ground0664.png
# /kaggle/input/DataSet/Train Images/clean0449.png
# /kaggle/input/DataSet/Train Images/clean0500.png
# /kaggle/input/DataSet/Train Images/clean1205.png
# /kaggle/input/DataSet/Train Images/ground2351.png
# /kaggle/input/DataSet/Train Images/ground2575.png
# /kaggle/input/DataSet/Train Images/clean1553.png
# /kaggle/input/DataSet/Train Images/clean4823.png
# /kaggle/input/DataSet/Train Images/ground5549.png
# /kaggle/input/DataSet/Train Images/ground1811.png
# /kaggle/input/DataSet/Train Images/clean2979.png
# /kaggle/input/DataSet/Train Images/ground2526.png
# /kaggle/input/DataSet/Train Images/ground1802.png
# /kaggle/input/DataSet/Train Images/ground3675.png
# /kaggle/input/DataSet/Train Images/clean3178.png
# /kaggle/input/DataSet/Train Images/ground3831.png
# /kaggle/input/DataSet/Train Images/clean1735.png
# /kaggle/input/DataSet/Train Images/ground5476.png
# /kaggle/input/DataSet/Train Images/clean4988.png
# /kaggle/input/DataSet/Train Images/clean3362.png
# /kaggle/input/DataSet/Train Images/ground1634.png
# /kaggle/input/DataSet/Train Images/ground1644.png
# /kaggle/input/DataSet/Train Images/clean2015.png
# /kaggle/input/DataSet/Train Images/ground2310.png
# /kaggle/input/DataSet/Train Images/clean1797.png
# /kaggle/input/DataSet/Train Images/ground1751.png
# /kaggle/input/DataSet/Train Images/ground5672.png
# /kaggle/input/DataSet/Train Images/clean0722.png
# /kaggle/input/DataSet/Train Images/ground1827.png
# /kaggle/input/DataSet/Train Images/ground1913.png
# /kaggle/input/DataSet/Train Images/clean4427.png
# /kaggle/input/DataSet/Train Images/clean3633.png
# /kaggle/input/DataSet/Train Images/clean0827.png
# /kaggle/input/DataSet/Train Images/ground0515.png
# /kaggle/input/DataSet/Train Images/clean2199.png
# /kaggle/input/DataSet/Train Images/ground2097.png
# /kaggle/input/DataSet/Train Images/ground5281.png
# /kaggle/input/DataSet/Train Images/clean0790.png
# /kaggle/input/DataSet/Train Images/ground0693.png
# /kaggle/input/DataSet/Train Images/ground4561.png
# /kaggle/input/DataSet/Train Images/ground4981.png
# /kaggle/input/DataSet/Train Images/ground3716.png
# /kaggle/input/DataSet/Train Images/ground3710.png
# /kaggle/input/DataSet/Train Images/clean5531.png
# /kaggle/input/DataSet/Train Images/clean3512.png
# /kaggle/input/DataSet/Train Images/ground0968.png
# /kaggle/input/DataSet/Train Images/clean0981.png
# /kaggle/input/DataSet/Train Images/clean1830.png
# /kaggle/input/DataSet/Train Images/clean1049.png
# /kaggle/input/DataSet/Train Images/clean0085.png
# /kaggle/input/DataSet/Train Images/ground1786.png
# /kaggle/input/DataSet/Train Images/ground1147.png
# /kaggle/input/DataSet/Train Images/ground5812.png
# /kaggle/input/DataSet/Train Images/ground5931.png
# /kaggle/input/DataSet/Train Images/clean2665.png
# /kaggle/input/DataSet/Train Images/ground4654.png
# /kaggle/input/DataSet/Train Images/clean0898.png
# /kaggle/input/DataSet/Train Images/clean4626.png
# /kaggle/input/DataSet/Train Images/ground5848.png
# /kaggle/input/DataSet/Train Images/clean4228.png
# /kaggle/input/DataSet/Train Images/ground0651.png
# /kaggle/input/DataSet/Train Images/ground5719.png
# /kaggle/input/DataSet/Train Images/clean4243.png
# /kaggle/input/DataSet/Train Images/ground2553.png
# /kaggle/input/DataSet/Train Images/clean5068.png
# /kaggle/input/DataSet/Train Images/clean4919.png
# /kaggle/input/DataSet/Train Images/ground4857.png
# /kaggle/input/DataSet/Train Images/clean5566.png
# /kaggle/input/DataSet/Train Images/clean1113.png
# /kaggle/input/DataSet/Train Images/ground1550.png
# /kaggle/input/DataSet/Train Images/ground5233.png
# /kaggle/input/DataSet/Train Images/clean3856.png
# /kaggle/input/DataSet/Train Images/ground1397.png
# /kaggle/input/DataSet/Train Images/clean3858.png
# /kaggle/input/DataSet/Train Images/ground5421.png
# /kaggle/input/DataSet/Train Images/clean3521.png
# /kaggle/input/DataSet/Train Images/clean2233.png
# /kaggle/input/DataSet/Train Images/clean3988.png
# /kaggle/input/DataSet/Train Images/clean0259.png
# /kaggle/input/DataSet/Train Images/ground0528.png
# /kaggle/input/DataSet/Train Images/ground3632.png
# /kaggle/input/DataSet/Train Images/clean1097.png
# /kaggle/input/DataSet/Train Images/clean5985.png
# /kaggle/input/DataSet/Train Images/clean2554.png
# /kaggle/input/DataSet/Train Images/clean5290.png
# /kaggle/input/DataSet/Train Images/ground5120.png
# /kaggle/input/DataSet/Train Images/ground1032.png
# /kaggle/input/DataSet/Train Images/ground5838.png
# /kaggle/input/DataSet/Train Images/ground1753.png
# /kaggle/input/DataSet/Train Images/clean3067.png
# /kaggle/input/DataSet/Train Images/ground4460.png
# /kaggle/input/DataSet/Train Images/ground3826.png
# /kaggle/input/DataSet/Train Images/ground0432.png
# /kaggle/input/DataSet/Train Images/ground2321.png
# /kaggle/input/DataSet/Train Images/clean2857.png
# /kaggle/input/DataSet/Train Images/ground0786.png
# /kaggle/input/DataSet/Train Images/clean3696.png
# /kaggle/input/DataSet/Train Images/ground1429.png
# /kaggle/input/DataSet/Train Images/clean3553.png
# /kaggle/input/DataSet/Train Images/clean0284.png
# /kaggle/input/DataSet/Train Images/ground5430.png
# /kaggle/input/DataSet/Train Images/clean2506.png
# /kaggle/input/DataSet/Train Images/clean2731.png
# /kaggle/input/DataSet/Train Images/ground1089.png
# /kaggle/input/DataSet/Train Images/clean4025.png
# /kaggle/input/DataSet/Train Images/clean4551.png
# /kaggle/input/DataSet/Train Images/ground3429.png
# /kaggle/input/DataSet/Train Images/ground5773.png
# /kaggle/input/DataSet/Train Images/clean1170.png
# /kaggle/input/DataSet/Train Images/ground1034.png
# /kaggle/input/DataSet/Train Images/clean3572.png
# /kaggle/input/DataSet/Train Images/clean4387.png
# /kaggle/input/DataSet/Train Images/clean5873.png
# /kaggle/input/DataSet/Train Images/clean0572.png
# /kaggle/input/DataSet/Train Images/ground2594.png
# /kaggle/input/DataSet/Train Images/clean1099.png
# /kaggle/input/DataSet/Train Images/clean4498.png
# /kaggle/input/DataSet/Train Images/ground2696.png
# /kaggle/input/DataSet/Train Images/clean3848.png
# /kaggle/input/DataSet/Train Images/ground0502.png
# /kaggle/input/DataSet/Train Images/ground0048.png
# /kaggle/input/DataSet/Train Images/ground0618.png
# /kaggle/input/DataSet/Train Images/clean0538.png
# /kaggle/input/DataSet/Train Images/clean4933.png
# /kaggle/input/DataSet/Train Images/ground4657.png
# /kaggle/input/DataSet/Train Images/ground5627.png
# /kaggle/input/DataSet/Train Images/ground5288.png
# /kaggle/input/DataSet/Train Images/ground5958.png
# /kaggle/input/DataSet/Train Images/ground5443.png
# /kaggle/input/DataSet/Train Images/clean1044.png
# /kaggle/input/DataSet/Train Images/clean3212.png
# /kaggle/input/DataSet/Train Images/clean4190.png
# /kaggle/input/DataSet/Train Images/ground0938.png
# /kaggle/input/DataSet/Train Images/ground3999.png
# /kaggle/input/DataSet/Train Images/clean2655.png
# /kaggle/input/DataSet/Train Images/clean2663.png
# /kaggle/input/DataSet/Train Images/clean2190.png
# /kaggle/input/DataSet/Train Images/ground5037.png
# /kaggle/input/DataSet/Train Images/ground0359.png
# /kaggle/input/DataSet/Train Images/clean0351.png
# /kaggle/input/DataSet/Train Images/ground3920.png
# /kaggle/input/DataSet/Train Images/ground1618.png
# /kaggle/input/DataSet/Train Images/ground3079.png
# /kaggle/input/DataSet/Train Images/clean3816.png
# /kaggle/input/DataSet/Train Images/ground2585.png
# /kaggle/input/DataSet/Train Images/ground3828.png
# /kaggle/input/DataSet/Train Images/clean1462.png
# /kaggle/input/DataSet/Train Images/clean0941.png
# /kaggle/input/DataSet/Train Images/clean0101.png
# /kaggle/input/DataSet/Train Images/ground5915.png
# /kaggle/input/DataSet/Train Images/ground4126.png
# /kaggle/input/DataSet/Train Images/clean3699.png
# /kaggle/input/DataSet/Train Images/clean3446.png
# /kaggle/input/DataSet/Train Images/ground0267.png
# /kaggle/input/DataSet/Train Images/ground5161.png
# /kaggle/input/DataSet/Train Images/ground0333.png
# /kaggle/input/DataSet/Train Images/clean0309.png
# /kaggle/input/DataSet/Train Images/clean5479.png
# /kaggle/input/DataSet/Train Images/ground2784.png
# /kaggle/input/DataSet/Train Images/ground0031.png
# /kaggle/input/DataSet/Train Images/clean0029.png
# /kaggle/input/DataSet/Train Images/ground4882.png
# /kaggle/input/DataSet/Train Images/clean4086.png
# /kaggle/input/DataSet/Train Images/ground0136.png
# /kaggle/input/DataSet/Train Images/ground2129.png
# /kaggle/input/DataSet/Train Images/clean2876.png
# /kaggle/input/DataSet/Train Images/clean4812.png
# /kaggle/input/DataSet/Train Images/clean2575.png
# /kaggle/input/DataSet/Train Images/ground2877.png
# /kaggle/input/DataSet/Train Images/ground1194.png
# /kaggle/input/DataSet/Train Images/ground5755.png
# /kaggle/input/DataSet/Train Images/clean3895.png
# /kaggle/input/DataSet/Train Images/clean3893.png
# /kaggle/input/DataSet/Train Images/clean3410.png
# /kaggle/input/DataSet/Train Images/clean5850.png
# /kaggle/input/DataSet/Train Images/ground3946.png
# /kaggle/input/DataSet/Train Images/clean0708.png
# /kaggle/input/DataSet/Train Images/clean3788.png
# /kaggle/input/DataSet/Train Images/ground0144.png
# /kaggle/input/DataSet/Train Images/ground1248.png
# /kaggle/input/DataSet/Train Images/clean1065.png
# /kaggle/input/DataSet/Train Images/ground1660.png
# /kaggle/input/DataSet/Train Images/ground4016.png
# /kaggle/input/DataSet/Train Images/clean5589.png
# /kaggle/input/DataSet/Train Images/clean0405.png
# /kaggle/input/DataSet/Train Images/ground1399.png
# /kaggle/input/DataSet/Train Images/clean4893.png
# /kaggle/input/DataSet/Train Images/ground2705.png
# /kaggle/input/DataSet/Train Images/clean0756.png
# /kaggle/input/DataSet/Train Images/clean3862.png
# /kaggle/input/DataSet/Train Images/ground1162.png
# /kaggle/input/DataSet/Train Images/clean3892.png
# /kaggle/input/DataSet/Train Images/ground4655.png
# /kaggle/input/DataSet/Train Images/ground4919.png
# /kaggle/input/DataSet/Train Images/ground0755.png
# /kaggle/input/DataSet/Train Images/ground4808.png
# /kaggle/input/DataSet/Train Images/clean2996.png
# /kaggle/input/DataSet/Train Images/clean0669.png
# /kaggle/input/DataSet/Train Images/ground1480.png
# /kaggle/input/DataSet/Train Images/clean5384.png
# /kaggle/input/DataSet/Train Images/clean5818.png
# /kaggle/input/DataSet/Train Images/ground4275.png
# /kaggle/input/DataSet/Train Images/clean2781.png
# /kaggle/input/DataSet/Train Images/clean4434.png
# /kaggle/input/DataSet/Train Images/clean2658.png
# /kaggle/input/DataSet/Train Images/ground3264.png
# /kaggle/input/DataSet/Train Images/clean1002.png
# /kaggle/input/DataSet/Train Images/clean4799.png
# /kaggle/input/DataSet/Train Images/clean0320.png
# /kaggle/input/DataSet/Train Images/ground2684.png
# /kaggle/input/DataSet/Train Images/ground0919.png
# /kaggle/input/DataSet/Train Images/ground3416.png
# /kaggle/input/DataSet/Train Images/clean5745.png
# /kaggle/input/DataSet/Train Images/ground4079.png
# /kaggle/input/DataSet/Train Images/ground2000.png
# /kaggle/input/DataSet/Train Images/ground2348.png
# /kaggle/input/DataSet/Train Images/ground1545.png
# /kaggle/input/DataSet/Train Images/clean2574.png
# /kaggle/input/DataSet/Train Images/ground3381.png
# /kaggle/input/DataSet/Train Images/ground0793.png
# /kaggle/input/DataSet/Train Images/clean4428.png
# /kaggle/input/DataSet/Train Images/clean1211.png

# %%
path= '/kaggle/input/DataSet/'
k= '/kaggle/input/DataSet/train.csv'
p ='/kaggle/input/DataSet/test.csv'

# %%
train=pd.read_csv(k)
test=pd.read_csv(p)

# %%
train.head()
# Out:
#        Image_File  Class
# 0   clean2416.png  Large
# 1  ground4022.png  Small
# 2  ground0340.png  Small
# 3  ground2110.png  Small
# 4   clean1581.png  Large

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import cv2
import glob

# %%
from pathlib import Path
from fastai import *
from fastai.vision import *
import torch
from fastai.callbacks.hooks import *

# %%
# !pwd
# Out:
# /kaggle/working

# %%
path ='/kaggle/input/DataSet/Train Images/'
tfms = get_transforms(flip_vert=False,max_zoom=1.0,max_warp=0,do_flip=False,xtra_tfms=[cutout()])
data = (ImageList.from_csv(path, csv_name = '../train.csv')
        .split_by_rand_pct()              
        .label_from_df()            
        .add_test_folder(test_folder = 'Test Images')              
        .transform(tfms, size=400)
        .databunch(num_workers=0,bs=8))

# %%
## to see the images in train with there labels
data.show_batch(rows=3, figsize=(8,10))

# %%
## print the target classes
print(data.classes)
# Out:
# ['Large', 'Small']

# %%
## load the pretrained imagenet model
## you can try other models from this link
## https://docs.fast.ai/vision.models.html
learn = cnn_learner(data, models.densenet161, metrics=[error_rate, accuracy], model_dir="/tmp/model/")
# Out:
# Downloading: "https://download.pytorch.org/models/densenet161-8d451a50.pth" to /tmp/.cache/torch/checkpoints/densenet161-8d451a50.pth
# 100%|██████████| 110M/110M [00:01<00:00, 68.2MB/s]

# %%
from fastai import *
from fastai.vision import *
from sklearn.model_selection import StratifiedKFold
from pathlib import Path
import shutil
from sklearn.metrics import f1_score, confusion_matrix

np.random.seed(1786)
ROOT = "/tmp/data2"

# %%
def read_data(root):
    train_df = pd.read_csv(k)
    test_df = pd.read_csv(p)
    return train_df, test_df

# %%
class SaveBestModel(Recorder):
    def __init__(self, learn,name='best_model'):
        super().__init__(learn)
        self.name = name
        self.best_loss = None
        self.best_acc = None
        self.save_method = self.save_when_acc
        
    def save_when_acc(self, metrics):        
        loss, acc = metrics[0], metrics[1]
        if (self.best_acc is None) or (acc > self.best_acc) or (loss < self.best_loss):
            self.best_acc = acc
            self.best_loss = loss
            self.learn.save(f'{self.name}')
            print("Save the best acc {:.5f}".format(self.best_acc))
        elif acc == self.best_acc and  loss < self.best_loss:
            self.best_loss = loss
            self.learn.save(f'{self.name}')
            print("Acc is eq,Save the lower loss {:.5f}".format(self.best_loss))
            
    def on_epoch_end(self,last_metrics=MetricsList,**kwargs:Any):
        self.save_method(last_metrics)

# %%
#Path(ROOT).mkdir(exist_ok=True, parents=True)
src1 = "/kaggle/input/DataSet/"
shutil.copytree(src1, ROOT)


if __name__=="__main__":
    train_df, test_df = read_data(ROOT)
    print(train_df.shape, test_df.shape)
    
    cvlist = list(StratifiedKFold(8, random_state=12345786).split(train_df, train_df.Class))
    
    tfms1 = get_transforms(max_zoom=1.5)
    test_preds_all = []
    val_preds_all = []
    for i in range(1):
        print("Starting fold {}".format(i))
        tr_idx, val_idx = cvlist[i]
        print(tr_idx.shape, val_idx.shape)
        src = (ImageList.from_df(train_df, path=ROOT, folder="Train Images").split_by_idxs(tr_idx, val_idx)
                                                            .label_from_df())
        data = ImageDataBunch.create_from_ll(src, ds_tfms=tfms1, size=400, bs=8, resize_method=3).normalize(imagenet_stats)
        data.add_test(ImageList.from_df(test_df, path=ROOT, folder="Test Images"))
        learn = cnn_learner(data, models.densenet169, metrics=accuracy, ps=0.5)
        # learn.model[0].load_state_dict(torch.load("../input/save-body-weights-marvel/bestmodel_body.path"))
        cb = SaveBestModel(learn, name="bestmodel_{}".format(i))
        #learn.fit(1, callbacks=cb)
        learn.fit_one_cycle(4)
        learn.unfreeze()
        #learn.fit_one_cycle(10, max_lr=1e-4, callbacks=[cb])
        #learn.fit_one_cycle(10, max_lr=5e-5, callbacks=[cb])
        #learn.fit_one_cycle(10, max_lr=1e-5, callbacks=[cb])
        #learn.fit_one_cycle(10, max_lr=5e-6, callbacks=[cb])
        learn.fit_one_cycle(5, max_lr=1e-6, callbacks=[cb])
        learn.load("bestmodel_{}".format(i))
        val_preds, y = learn.TTA(ds_type=DatasetType.Valid)
        val_preds = np.exp(val_preds.numpy())
        print("F1 score for this fold ",f1_score(y.numpy(), np.argmax(val_preds,axis=1), average='weighted'))
        test_preds = np.exp(learn.TTA(ds_type=DatasetType.Test)[0].numpy())
        test_preds_all.append(test_preds)
        val_preds_all.append(val_preds)
        fname = "bestmodel_{}.pth".format(i)
        src = str(Path(ROOT) / "models" / fname)
        shutil.copy(src, fname)
    test_preds_all = np.mean(test_preds_all, axis=0)
    val_preds_all = np.concatenate(val_preds_all, axis=0)

    np.save("test_preds.npy", test_preds_all)
    np.save("val_preds.npy", val_preds_all)
    sub = test_df[["Image_File"]]
    sub["Class"] = np.argmax(test_preds_all, axis=1)
    sub.to_csv("subv1.csv", index=False)

# %%
preds = np.argmax(test_preds_all, 1)
preds
# Out:
# array([1, 1, 1, 1, ..., 0, 0, 0, 0])

# %%
a = np.array(preds)
# Out:
# [1 1 1 1 ... 0 0 0 0]
# <built-in method max of numpy.ndarray object at 0x7efecd8038a0>
# Image (3, 480, 720)

# %%
df = pd.DataFrame({'Image_File':a}, columns=['Image_File']
                  {'Class':test['Class']}, columns=['Class'])
df.to_csv('gamerr.csv', index=False)

# %%
from IPython.display import HTML
def create_download_link(title = "Download CSV file", filename = "gamerr.csv"):  
    html = '<a href={filename}>{title}</a>'
    html = html.format(title=title,filename=filename)
    return HTML(html)

# %%
create_download_link(filename = 'gamerr.csv')
# Out:
# <a href=gamerr.csv>Download CSV file</a>
